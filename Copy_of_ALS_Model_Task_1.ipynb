# %% [markdown]
# <a href="https://colab.research.google.com/github/fr3ooon1/iban/blob/develop/Copy_of_ALS_Model_Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
